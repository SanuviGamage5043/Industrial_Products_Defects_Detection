# %%
# !git clone https://github.com/SanuviGamage5043/Industrial_Products_Defects_Detection.git
# %cd Industrial_Products_Defects_Detection
# Out:
# Cloning into 'Industrial_Products_Defects_Detection'...
# remote: Enumerating objects: 4410, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 4410 (delta 11), reused 14 (delta 1), pack-reused 4377 (from 3)
# Receiving objects: 100% (4410/4410), 146.17 MiB | 34.30 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# Updating files: 100% (8075/8075), done.
# /content/Industrial_Products_Defects_Detection

# %%
# !pip install ultralytics
# !pip install opencv-python
# !pip install matplotlib

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import torch
import cv2
import os

print("GPU Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: False

# %%
model = YOLO("yolov8n.pt")

# %%
data_yaml = """
path: dataset_yolo

train: images/train
val: images/val
test: images/test

names:
  0: blowhole
  1: break
  2: crack
  3: fray
  4: uneven
"""

with open("dataset.yaml", "w") as f:
    f.write(data_yaml)

print("dataset.yaml created")
# Out:
# dataset.yaml created

# %%
results = model.train(
    data="dataset.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    lr0=0.001,
    patience=10,
    device='cpu'
)
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
metrics = model.val()

# %%
best_model = YOLO(
    "runs/detect/train/weights/best.pt"
)

results = best_model.predict(
    "../dataset_yolo/images/test/sample.jpg",
    save=True,
    conf=0.25
)

# %%
result_img = cv2.imread(
    "runs/detect/predict/sample.jpg"
)

result_img = cv2.cvtColor(
    result_img,
    cv2.COLOR_BGR2RGB
)

plt.figure(figsize=(10,8))
plt.imshow(result_img)
plt.axis("off")
plt.title("YOLOv8 Prediction")
plt.show()

# %%
img = plt.imread(
    "runs/detect/train/results.png"
)

plt.figure(figsize=(12,8))
plt.imshow(img)
plt.axis("off")
plt.title("Training Results")
plt.show()
